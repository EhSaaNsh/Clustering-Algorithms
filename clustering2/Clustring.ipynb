# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:/Users/Ehsan/Desktop/Customer_Data.csv')
data
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df = pd.DataFrame(data)
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df2=df.dropna()
df3 = df2.drop('CUST_ID' , axis=1)

#paksazi dataset

# %%
df3.corr()

#correlation
# Out:
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000           0.310140   0.176083
# BALANCE_FREQUENCY                 0.310140           1.000000   0.122635
# PURCHASES                         0.176083           0.122635   1.000000
# ONEOFF_PURCHASES                  0.159985           0.095254   0.916780
# INSTALLMENTS_PURCHASES            0.122109           0.114739   0.679259
# CASH_ADVANCE                      0.495586           0.089036  -0.053760
# PURCHASES_FREQUENCY              -0.088459           0.228158   0.393000
# ONEOFF_PURCHASES_FREQUENCY        0.063832           0.187467   0.497384
# PURCHASES_INSTALLMENTS_FREQUENCY -0.069582           0.184159   0.316025
# CASH_ADVANCE_FREQUENCY            0.445307           0.181132  -0.124863
# CASH_ADVANCE_TRX                  0.382388           0.133265  -0.070277
# PURCHASES_TRX                     0.147887           0.183095   0.688732
# ...

# %%
X = df3['BALANCE']
y = df3['PURCHASES']

## entekhab 2 soton ke cluster ra behtar neshan midahand

# %%
plt.figure(figsize=(15,8))
plt.scatter( X ,y, 
   c='white', marker='.',
   edgecolor='black', s=50
)
plt.show()

## plot 2 soton

# %%
km_set={'init':'random' , 'n_init':10 , 'max_iter':300 , 'random_state':42}

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_features =scaler.fit_transform(df3)

##

# %%
from sklearn.cluster import KMeans

l = []

for k in range(1,11):
    km = KMeans(n_clusters=k , **km_set)
    km.fit(scaled_features)
    l.append(km.inertia_)
    
## entekhab behtarin k

# %%
plt.style.use('fivethirtyeight')
plt.xticks(range(1,11))
plt.xlabel('number of cluster')
plt.ylabel('inertia')
plt.plot(range(1,11),l)

# %%
from kneed import KneeLocator
k1=KneeLocator(range(1,11) , l ,curve='convex' , direction='decreasing')
k1.elbow

## behtarin k baray algorithm k-means barabar 4 ast
# Out:
# 4

# %%
km = KMeans(
    n_clusters=4, init='random',
    n_init=10, max_iter=300, 
    tol=1e-04, random_state=20
)
y_km = km.fit_predict(scaled_features)

## cluster bandi ba k-means

# %%
print(y_km)
# Out:
# [1 0 3 ... 3 1 1]

# %%
plt.figure(figsize=(15,8))
centroids = km.cluster_centers_
plt.scatter(X,y,c=km.labels_.astype(float))
plt.scatter(centroids[:,1],centroids[:,2] , c='red')
plt.xlabel('BALANCE')
plt.ylabel('PURCHASES')
plt.show()

## plot cluster k-means

# %%
aff_set = { 'damping':0.9 , 'max_iter':1000 , 'convergence_iter':20 , 'affinity':'euclidean' ,'random_state':40 ,'preference':12.4}

# %%
from sklearn.cluster import AffinityPropagation
clustering = AffinityPropagation(**aff_set)

##cluster bandi ba algorithm affinity

# %%
a=clustering.fit(scaled_features)

# %%
a.cluster_centers_
# Out:
# array([[-0.74462486, -0.37004679, -0.42918384, ..., -0.30550763,
#         -0.53772694,  0.35518066],
#        [ 0.76415211,  0.06767893, -0.47320819, ...,  0.08768873,
#          0.21238001,  0.35518066],
#        [ 0.42660239,  0.50540465, -0.11641251, ..., -0.09990611,
#         -0.53772694,  0.35518066],
#        ...,
#        [-0.75297728, -0.29709491, -0.40657175, ..., -0.32957217,
#          0.30614422, -4.22180042],
#        [-0.75772142, -0.29709491, -0.47320819, ..., -0.34081076,
#          0.30614422, -4.22180042],
#        [-0.58627829, -1.09958965,  0.03129519, ..., -0.32709767,
#         -0.53772694, -4.22180042]])

# %%
plt.figure(figsize=(15,8))
centroids = a.cluster_centers_
plt.scatter(X,y,c=a.labels_.astype(float))
plt.scatter(centroids[:,0],centroids[:,1] , c='red')
plt.xlabel('BALANCE')
plt.ylabel('PURCHASES')
plt.show()

##plot cluster affinity

# %%
from sklearn.cluster import DBSCAN
clustering = DBSCAN(eps=1, min_samples=2).fit(scaled_features)

## cluster bandi ba dbscan

# %%
clustering.labels_
# Out:
# array([ 0, -1,  0, ...,  0, -1, -1], dtype=int64)

# %%
clustering.core_sample_indices_
# Out:
# array([   0,    2,    3, ..., 8631, 8632, 8633], dtype=int64)

# %%
plt.figure(figsize=(15,8))
plt.scatter(X,y,c=clustering.labels_.astype(float))
plt.xlabel('BALANCE')
plt.ylabel('PURCHASES')

##plot cluster DBSCAN
# Out:
# Text(0, 0.5, 'PURCHASES')

# %%
from sklearn.cluster import MeanShift
cl = MeanShift(bandwidth=2).fit(scaled_features)

## cluster bandi ba MeanShift

# %%
cl.labels_
# Out:
# array([  0, 277,   4, ...,   5,   3,  69], dtype=int64)

# %%
plt.figure(figsize=(15,8))
plt.scatter(X,y,c=cl.labels_.astype(float))
plt.xlabel('BALANCE')
plt.ylabel('PURCHASES')

## plot cluster Meanshift
# Out:
# Text(0, 0.5, 'PURCHASES')

# %%
from sklearn.mixture import GaussianMixture
clm=GaussianMixture(n_components=2, random_state=0).fit(scaled_features)

## cluster bandi ba GussianMixture

# %%
clm.means_
# Out:
# array([[ 0.22608099,  0.31339318,  0.63529972,  0.51575703,  0.55452234,
#         -0.02966981,  0.75312504,  0.81164574,  0.53732379, -0.16975369,
#         -0.09481169,  0.7307303 ,  0.39092153,  0.43615205,  0.29084739,
#          0.17478735,  0.2015662 ],
#        [-0.12483454, -0.17304549, -0.35079178, -0.2847842 , -0.30618915,
#          0.0163827 , -0.41585108, -0.4481643 , -0.29669267,  0.09373245,
#          0.05235192, -0.40348543, -0.21585412, -0.24082894, -0.16059644,
#         -0.09651187, -0.11129828]])

# %%
from sklearn.cluster import AgglomerativeClustering
ag= AgglomerativeClustering(n_clusters=4,compute_full_tree=bool).fit(scaled_features)

## cluster bandi ba Agglomerative

# %%
ag.labels_
# Out:
# array([0, 2, 3, ..., 0, 0, 0], dtype=int64)

# %%
plt.figure(figsize=(15,8))
plt.scatter(X,y,c=ag.labels_.astype(float))
plt.xlabel('BALANCE')
plt.ylabel('PURCHASES')

##plot cluster Agglomerative
# Out:
# Text(0, 0.5, 'PURCHASES')
